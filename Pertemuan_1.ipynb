# %% [markdown]
# <a href="https://colab.research.google.com/github/rico8428/Pertemuan_1/blob/main/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama = "Rico"
umur = 21
jurusan = "RPE"
semester = 3
matakuliah = "Pemrograman Dasar"
status_lulus = False

print(nama)
print(umur)
print(jurusan)
print(semester)
print(matakuliah)
print(status_lulus)
# Out:
# Rico
# 21
# RPE
# 3
# Pemrograman Dasar
# False
